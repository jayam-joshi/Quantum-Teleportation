# %%
from qiskit import *

# %%
from math import pi
state_package = QuantumRegister(1)
alice = QuantumRegister(1)
bob = QuantumRegister(1)
output = ClassicalRegister(3)
circuit = QuantumCircuit(state_package,alice,bob,output)

# %%
circuit.rx(pi/8, state_package)
circuit.barrier()
from qiskit.tools.visualization import plot_bloch_multivector
sim = Aer.get_backend('statevector_simulator')
result_i = execute(circuit, backend=sim).result()
statevector_i = result_i.get_statevector()
print(statevector_i)
circuit.draw('mpl')
plot_bloch_multivector(statevector_i)
# Out:
# [0.98078528+0.j         0.        -0.19509032j 0.        +0.j
#  0.        +0.j         0.        +0.j         0.        +0.j
#  0.        +0.j         0.        +0.j        ]

# %%
circuit.h(alice)
circuit.cx(alice,bob)
circuit.barrier()

# %%
circuit.cx(state_package,alice)
circuit.h(state_package)
circuit.barrier()

# %%
circuit.measure([state_package[0],alice[0]],[output[0],output[1]])
circuit.barrier()

# %%
circuit.cz(state_package,bob)
circuit.cx(alice,bob)
circuit.draw('mpl')

# %%
IBMQ.load_account()
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
provider = IBMQ.get_provider('ibm-q')
qcomp = provider.get_backend('ibmq_16_melbourne')
job = execute(circuit, backend=qcomp)
from qiskit.tools.monitor import job_monitor
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
from qiskit.tools.visualization import plot_histogram
result = job.result()
plot_histogram(result.get_counts(circuit))
res = execute(circuit, backend=sim).result()
statevector = res.get_statevector()
plot_bloch_multivector(statevector)
